# %%
import numpy as np
import matplotlib.pyplot as plt

# histogram our data with numpy

#data = np.array([1] * 24 + [2] * 19 + [3] * 15 + [4] * 12 + [5] * 18 + [6] * 25) 

#data = np.random.randint(1, 7, 10000)
two = 1
three = 2
four = 5
five = 3
six = 15
seven = 9
eight = 4
nine = 6
ten = 5
eleven = 5 
twelve = 1

#data = np.array([2] * two + [3] * three + [4] * four + [5] * five + [6] * six
#        + [7] * seven + [8] * eight + [9] * nine + [10] * ten + [11] * eleven + [12] * twelve) 
num_rolls = 3
rolls_1 = np.random.randint(1, 7, 10000)
rolls_2 = np.random.randint(1, 7, 10000)
rolls_3 = np.random.randint(1, 7, 10000)
data = [rolls_1[i] + rolls_2[i] + rolls_3[i] for i in range(len(rolls_1))]

b = num_rolls * 6 - num_rolls + 1

plt.hist(data, bins = b) 
plt.title("histogram") 
plt.show()
