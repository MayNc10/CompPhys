# %%
# put the needed libraries first, here at the top
import numpy as np # math
import matplotlib.pyplot as plt # graphing

#Knowns - what variables did the problem give us? don't forget units!
h = float(input("How high is the ball dropped from? ")) # get input from user and typecast it, meters
vh = float(input("What is the ball's horizontal velocity"))

#in addition to the known values, are there any assumed values?

t = 0 # seconds
vv = 0 # meters / second
x = 0
a = -9.8 # meters / second squared, g

#We also want to update time incrementally with the Euler-Cromer method
dt = 0.001 # time step

#Lists - these will typically be used to create graphs, so think about what we want to graph! Don't forget units

tlist = [t] #s
hlist = [h] #m
xlist = [x] #x
vvlist = [vv] #v

#The Motion - Using a while loop, we update the various variables of the object

while h > 0: #example - while t < 10:
    vv += a * dt #what physics is happening here? v = a * t
    h += vv * dt #what physics is happening here? x = v * t
    x += vh * dt
    t += dt #what physics is happening here? update time

    #we also need to update our lists
    tlist.append(t) # add time to list
    xlist.append(x) # add distance to list
    hlist.append(h) # add height to list
    vvlist.append(vv) # add velocity to list


#Graphs - what are the common physics graphs you'd be asked for a question like this? distance vs. time, velocity vs. time

fig, axs = plt.subplots(3)
fig.suptitle("Ball Drop Graphs")

axs[0].scatter(tlist, hlist, color='blue');   # this makes a scatterplot!
axs[0].set_xlabel("Time (s)") # x is time
axs[0].set_ylabel("Height (m)") # y is height
axs[0].set_title("Ball Height vs. Time") # title

axs[1].scatter(tlist, xlist, color='blue');   # this makes a scatterplot!
axs[1].set_xlabel("Time (s)") # x is time
axs[1].set_ylabel("Distance (m)") # y is height
axs[1].set_title("Ball Distance vs. Time") # title

axs[2].scatter(tlist, vvlist, color='purple');   # this makes a scatterplot!
axs[2].set_xlabel("Time (s)") # x is time
axs[2].set_ylabel("Velocity (m/s)") # y is velocity
axs[2].set_title("Ball Velocity vs. Time") # title

plt.tight_layout()
plt.show()

#How do we get the computer to tell us the answer? Where is this variable being stored? How do we print it out?
print(f"The ball takes {t} seconds to hit the ground when dropped from {hlist[0]} meters, with a final velocity of {vv} meters per second") 
    # show time taken and input height
# Out:
# The ball takes 5.000000000000004 seconds to hit the ground when dropped from 122.5 meters, with a final velocity of -48.99999999999515 meters per second
